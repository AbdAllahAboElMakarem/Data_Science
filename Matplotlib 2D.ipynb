# %%
from matplotlib import pyplot as plt

# %%
plt.plot([2,6,9],[5,6,9])

# %%
plt.plot([2,6,58],[12,6,4])

# %%
plt.plot([2,6,58],[12,6,4])
plt.title('Table')
plt.ylabel('Y')
plt.xlabel('N')
plt.show()

# %%
array_plt = ([4,56,7,8,3],[4,6,88,2,6])
plt.plot(array_plt)
plt.title('Table')
plt.ylabel('Y')
plt.xlabel('N')
plt.show()
